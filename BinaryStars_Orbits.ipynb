# %%
import pandas as pd
import numpy as np


df = pd.DataFrame(
    columns=[
        "primary_hip",
        "secondary_hip",
        "binary_period",
        "eccentricity",
        "inclination",
        "big_omega",
        "small_omega",
        "periastron_epoch",
        "semi_major",
        "bary_distance",
        "data_epoch",
        "bary_ra",
        "bary_dec",
        "bary_rv",
        "bary_pmra",
        "bary_pmdec",
        "primary_mass",
        "secondary_mass",
    ],
)

# alpha Cen A and B
df.loc[len(df)] = {
    "primary_hip": 71683,
    "secondary_hip": 71681,
    "binary_period": 79.762 * 365.25,
    "eccentricity": 0.51947,
    "inclination": 79.2430,
    "big_omega": 205.073,
    "small_omega": 231.519,
    "periastron_epoch": 2435314.751,
    "semi_major": 17.4930,
    "bary_distance": 1000.0 / 750.81,
    "data_epoch": 2458667.375,
    "bary_ra": 219.85892215,
    "bary_dec": -60.83163195,
    "bary_rv": -22.39,
    "bary_pmra": -3639.95,
    "bary_pmdec": 700.40,
    "primary_mass": 1.0788,
    "secondary_mass": 0.9092,
}
# Sirius A and B
df.loc[len(df)] = {
    "primary_hip": 32349,
    "secondary_hip": 2947050466531873024,
    "binary_period": 50.1284 * 365.25,
    "eccentricity": 0.59142,
    "inclination": 136.336,
    "big_omega": 45.400,
    "small_omega": 149.161,
    "periastron_epoch": 2449562.240375,
    "semi_major": 7.4957,
    "bary_distance": 1000.0 / 378.9,
    "data_epoch": 2451545.0,
    "bary_ra": 101.28715533,
    "bary_dec": -16.71611586,
    "bary_rv": -8.47,
    "bary_pmra": -506.3282841530055,
    "bary_pmdec": -1078.0683606557377,
    "primary_mass": 2.063,
    "secondary_mass": 1.018,
}

# 61 Cygni A and B
df.loc[len(df)] = {
    "primary_hip": 1872046609345556480,  # 104214
    "secondary_hip": 1872046574983497216,  # 104217
    "binary_period": 704.858 * 365.25,
    "eccentricity": 0.435,
    "inclination": 52.018,
    "big_omega": 174.56,
    "small_omega": 154.044,
    "periastron_epoch": 2340510.461,
    "semi_major": 24.57,
    "bary_distance": 1000.0 / 286.0054,
    "data_epoch": 2451545.0,
    "bary_ra": 316.7510710233,
    "bary_dec": 38.7599676093,
    "bary_rv": -65.034,
    "bary_pmra": 4135.09,
    "bary_pmdec": 3202.778,
    "primary_mass": 0.70,
    "secondary_mass": 0.63,
}

# Gamma Virginis A and B
df.loc[len(df)] = {
    "primary_hip": 3683687763520080384,  # 61941
    "secondary_hip": 3683687763520080256,
    "binary_period": 168.93 * 365.25,
    "eccentricity": 0.8825,
    "inclination": 148.82,
    "big_omega": 35.34,
    "small_omega": 255.02,
    "periastron_epoch": 2453531.2295,
    "semi_major": 3.662,
    "bary_distance": 1000.0 / 85.58,
    "data_epoch": 2451545.0,
    "bary_ra": 190.4149391943586,
    "bary_dec": -1.4494030396953002,
    "bary_rv": -19.8,
    "bary_pmra": -569.747,
    "bary_pmdec": 10.7155,
    "primary_mass": 1.4,
    "secondary_mass": 1.4,
}

# Alula Australis - ξ UMa - HIP 55203
df.loc[len(df)] = {
    "primary_hip": 756853643638639104,  # 55203
    "secondary_hip": 756853643637996160,
    "binary_period": 59.8903 * 365.25,
    "eccentricity": 0.40432,
    "inclination": 122.187,
    "big_omega": 100.939,
    "small_omega": 126.964,
    "periastron_epoch": 2427865.8425000003,
    "semi_major": 2.50442,
    "bary_distance": 1000.0 / 114.4867,
    "data_epoch": 2451545.0,
    "bary_ra": 169.54442668460666,
    "bary_dec": 31.52853473639239,
    "bary_rv": -17.5,
    "bary_pmra": -393.113693989071,
    "bary_pmdec": -599.1503387978142,
    "primary_mass": 0.97,
    "secondary_mass": 0.86,
}

# Achird - η Cas - HIP 3821
df.loc[len(df)] = {
    "primary_hip": 425040000962559616,  # 3821
    "secondary_hip": 425040000962497792,
    "binary_period": 479.27 * 365.25,
    "eccentricity": 0.497,
    "inclination": 35.6,
    "big_omega": 278.0,
    "small_omega": 269.8,
    "periastron_epoch": 2411341.9325,
    "semi_major": 12.040,
    "bary_distance": 1000.0 / 168.8322,
    "data_epoch": 2451545.0,
    "bary_ra": 12.283711400033505,
    "bary_dec": 57.813857274201595,
    "bary_rv": 8.5089,
    "bary_pmra": 1103.3904999999997,
    "bary_pmdec": -520.583625,
    "primary_mass": 0.95,
    "secondary_mass": 0.57,
}

# ε1 Lyr - HIP 91919
df.loc[len(df)] = {
    "primary_hip": 2098237660364079232,  # 91919
    "secondary_hip": 2098237656065233792,
    "binary_period": 2802.8 * 365.25,
    "eccentricity": 0.953,
    "inclination": 102.2,
    "big_omega": 149.6,
    "small_omega": 258.8,
    "periastron_epoch": 2411341.9325,
    "semi_major": 14.237,
    "bary_distance": 1000.0 / 20.4574,
    "data_epoch": 2470351.7225,
    "bary_ra": 281.08475708701553,
    "bary_dec": 39.67067855496124,
    "bary_rv": 32.25961538461539,
    "bary_pmra": 19.984807692307694,
    "bary_pmdec": 23.025403846153846,
    "primary_mass": 2.03,
    "secondary_mass": 1.61,
}

# ε2 Lyr - HIP 91926
df.loc[len(df)] = {
    "primary_hip": 2098202128093842432,  # 91926
    "secondary_hip": 2098202128100428288,
    "binary_period": 724.3 * 365.25,
    "eccentricity": 0.353,
    "inclination": 126.1,
    "big_omega": 26.5,
    "small_omega": 73.8,
    "periastron_epoch": 2533324.475,
    "semi_major": 2.920,
    "bary_distance": 1000.0 / 20.97,
    "data_epoch": 2470351.7225,
    "bary_ra": 281.0953758085716,
    "bary_dec": 39.613010644075835,
    "bary_rv": -26.117840375586855,
    "bary_pmra": 5.7759940089347666,
    "bary_pmdec": 57.50554153914594,
    "primary_mass": 2.11,
    "secondary_mass": 2.15,
}

# β Mus - HIP 62322
df.loc[len(df)] = {
    "primary_hip": 5855802671046171648,  # 62322
    "secondary_hip": 5855802671045627648,
    "binary_period": 479.27 * 365.25,
    "eccentricity": 0.497,
    "inclination": 35.6,
    "big_omega": 278.0,
    "small_omega": 269.8,
    "periastron_epoch": 2411341.9325,
    "semi_major": 12.040,
    "bary_distance": 1000.0 / 10.33,
    "data_epoch": 2470351.7225,
    "bary_ra": 191.56982860741647,
    "bary_dec": -68.10806846587313,
    "bary_rv": 42.0,
    "bary_pmra": -37.47949516527006,
    "bary_pmdec": -16.40962870405608,
    "primary_mass": 2.11,
    "secondary_mass": 2.15,
}

# Dalim - α For - HIP 14879
df.loc[len(df)] = {
    "primary_hip": 5059348952161258624,  # 14879
    "secondary_hip": 5059349158319689344,
    "binary_period": 268.2120 * 365.25,
    "eccentricity": 0.73704,
    "inclination": 81.484,
    "big_omega": 117.397,
    "small_omega": 43.023,
    "periastron_epoch": 2432336.977325,
    "semi_major": 3.96341,
    "bary_distance": 1000.0 / 71.22,
    "data_epoch": 2470351.7225,
    "bary_ra": 48.02016189207887,
    "bary_dec": -28.984593222987403,
    "bary_rv": -19.023605511848338,
    "bary_pmra": 353.699852158919,
    "bary_pmdec": 625.3625094672343,
    "primary_mass": 1.33,
    "secondary_mass": 0.78,
}

# ψ Vel - HIP 46651
df.loc[len(df)] = {
    "primary_hip": 5426587107145955712,  # 46651
    "secondary_hip": 5426587107149861120,
    "binary_period": 34.12 * 365.25,
    "eccentricity": 0.439,
    "inclination": 58.4,
    "big_omega": 288.2,
    "small_omega": 47.7,
    "periastron_epoch": 2432336.977325,
    "semi_major": 0.810,
    "bary_distance": 1000.0 / 54.4556,
    "data_epoch": 2453031.5675,
    "bary_ra": 142.67382931492276,
    "bary_dec": -40.46651215769516,
    "bary_rv": 8.8,
    "bary_pmra": -190.96888235294116,
    "bary_pmdec": 69.36568627450981,
    "primary_mass": 1.56,
    "secondary_mass": 1.5,
}

# ρ Oph - HIP 88601
df.loc[len(df)] = {
    "primary_hip": 4468557611984384512,  # 88601
    "secondary_hip": 4468557611977674496,
    "binary_period": 88.3983 * 365.25,
    "eccentricity": 0.49803,
    "inclination": 120.892,
    "big_omega": 121.692,
    "small_omega": 193.376,
    "periastron_epoch": 2413493.8394,
    "semi_major": 4.55038,
    "bary_distance": 1000.0 / 195.71184,
    "data_epoch": 2453031.5675,
    "bary_ra": 271.36509160183584,
    "bary_dec": 2.4947755106163902,
    "bary_rv": -6.87,
    "bary_pmra": 261.9856072570008,
    "bary_pmdec": -1090.3690455852434,
    "primary_mass": 0.9,
    "secondary_mass": 0.7,
}

# Zeta Herculis - HIP 81693 A and B
df.loc[len(df)] = {
    "primary_hip": 1312665361415345920,  # 81693
    "secondary_hip": 1312665361414730624,
    "binary_period": 34.45 * 365.25,
    "eccentricity": 0.46,
    "inclination": 131,
    "big_omega": 50,
    "small_omega": 111,
    "periastron_epoch": 2439747.425,
    "semi_major": 1.33,
    "bary_distance": 1000.0 / 93.32,
    "data_epoch": 2451545.0,
    "bary_ra": 250.3191978982520,
    "bary_dec": 31.6045838783600,
    "bary_rv": -67.80,
    "bary_pmra": -461.52,
    "bary_pmdec": 342.28,
    "primary_mass": 1.45,
    "secondary_mass": 0.98,
}

# Eta Ophiuchi - HIP 84012 A and B
df.loc[len(df)] = {
    "primary_hip": 84012,  # 84012
    "secondary_hip": 4136366183978856960,
    "binary_period": 87.58 * 365.25,
    "eccentricity": 0.950,
    "inclination": 95.2,
    "big_omega": 38.9,
    "small_omega": 274.8,
    "periastron_epoch": 2460559.37,
    "semi_major": 1.396,
    "bary_distance": 1000.0 / 36.91,
    "data_epoch": 2451545.0,
    "bary_ra": 257.59452871,
    "bary_dec": -15.72490664,
    "bary_rv": -2.40,
    "bary_pmra": 40.13,
    "bary_pmdec": 99.17,
    "primary_mass": 2.966,
    "secondary_mass": 3.478,
}

# Castor - HIP 36850 A and B
df.loc[len(df)] = {
    "primary_hip": 36850,  # 84012
    "secondary_hip": 892348694913501952,
    "binary_period": 459.1 * 365.25,
    "eccentricity": 0.3382,
    "inclination": 115.107,
    "big_omega": 41.304,
    "small_omega": 251.84,
    "periastron_epoch": 2436785, 
    "semi_major": 6.722,
    "bary_distance": 1000.0 / 66.356,
    "data_epoch": 2451545.0,
    "bary_ra": 113.64947164,
    "bary_dec": 31.88828222,
    "bary_rv": 2.057,
    "bary_pmra": -175.88,
    "bary_pmdec": -99.28,
    "primary_mass": 2.7569,
    "secondary_mass": 2.1755,
}

# turn some degree columns into radians
df["inclination"] = np.radians(df["inclination"])
df["big_omega"] = np.radians(df["big_omega"])
df["small_omega"] = np.radians(df["small_omega"])
df["bary_ra"] = np.radians(df["bary_ra"])
df["bary_dec"] = np.radians(df["bary_dec"])

# rename primary_hip to #primary_hip
df.rename(columns={"primary_hip": "#primary_hip"}, inplace=True)

df.to_csv("binary_orbitparam.dat", index=False, sep="\t")
